# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib notebook

# %%
df = pd.read_csv("C:/Users/elkha/Desktop/gdp_data/API_NY.GDP.MKTP.CD_DS2_en_csv_v2_1345540.csv", skiprows=4)

# %%
df
# Out:
#      Country Name Country Code     Indicator Name  Indicator Code  \
# 0           Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 1     Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 2          Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 3         Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 4         Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD
# ..            ...          ...                ...             ...
# 259        Kosovo          XKX  GDP (current US$)  NY.GDP.MKTP.CD
# 260   Yemen, Rep.          YEM  GDP (current US$)  NY.GDP.MKTP.CD
# 261  South Africa          ZAF  GDP (current US$)  NY.GDP.MKTP.CD
# 262        Zambia          ZMB  GDP (current US$)  NY.GDP.MKTP.CD
# 263      Zimbabwe          ZWE  GDP (current US$)  NY.GDP.MKTP.CD
#
#              1960          1961          1962          1963          1964  \
# 0             NaN           NaN           NaN           NaN           NaN
# ...

# %%
data_2019=df[['Country Name','2019']].sort_values(by='2019', ascending=False)

# %%
data_2019.head(15)
# Out:
#            Country Name          2019
# 249       United States  2.137442e+13
# 38                China  1.434290e+13
# 117               Japan  5.081770e+12
# 53              Germany  3.845630e+12
# 202          South Asia  3.597970e+12
# 107               India  2.875142e+12
# 79       United Kingdom  2.827113e+12
# 75               France  2.715518e+12
# 114               Italy  2.001244e+12
# 27               Brazil  1.839758e+12
# 33               Canada  1.736426e+12
# 200  Russian Federation  1.699877e+12
# 124         Korea, Rep.  1.642383e+12
# 68                Spain  1.394116e+12
# 11            Australia  1.392681e+12

# %%
print(data_2019.iloc(0)[16])
# Out:
# Country Name    European Union
# 2019               1.55928e+13
# Name: 71, dtype: object

# %%
top_15=data_2019.head(15)['Country Name']

# %%
top_15_countryname=[]
for i in range (len(top_15)):
    top_15_countryname.append(top_15.iloc(0)[i])

# %%
top_15_countryname
# Out:
# ['United States',
#  'China',
#  'Japan',
#  'Germany',
#  'South Asia',
#  'India',
#  'United Kingdom',
#  'France',
#  'Italy',
#  'Brazil',
#  'Canada',
#  'Russian Federation',
#  'Korea, Rep.',
#  'Spain',
#  'Australia']

# %%
df.sort_values?

# %%
country_names=df["Country Name"]

# %%
Country[0]
# Out:
# ('US', 'United States')

# %%
a= 'United States'

# %%
a in countries
# Out:
# True

# %%
countries=[]
for i in range (len(Country)): 
    countries.append(Country[i][1])

# %%
df.drop?

# %%
for index, row in df.iterrows(): 
    if ((row["Country Name"] in non_wanted )== True): 
        df.drop(index, inplace=True)

# %%
df
# Out:
#      Country Name Country Code     Indicator Name  Indicator Code  \
# 0           Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 1     Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 2          Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 3         Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 4         Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD
# ..            ...          ...                ...             ...
# 259        Kosovo          XKX  GDP (current US$)  NY.GDP.MKTP.CD
# 260   Yemen, Rep.          YEM  GDP (current US$)  NY.GDP.MKTP.CD
# 261  South Africa          ZAF  GDP (current US$)  NY.GDP.MKTP.CD
# 262        Zambia          ZMB  GDP (current US$)  NY.GDP.MKTP.CD
# 263      Zimbabwe          ZWE  GDP (current US$)  NY.GDP.MKTP.CD
#
#              1960          1961          1962          1963          1964  \
# 0             NaN           NaN           NaN           NaN           NaN
# ...

# %%
non_wanted=['Arab World',
            'Central Europe and the Baltics',
            'Channel Islands',
            'East Asia & Pacific (excluding high income)',
            'Early-demographic dividend',
            'East Asia & Pacific',
            'Europe & Central Asia (excluding high income)',
            'Europe & Central Asia', 
            'Euro area',
            'European Union',
            'Fragile and conflict affected situations',
            'High income',
            'Heavily indebted poor countries (HIPC)',
            'IBRD only',
            'IDA & IBRD total',
            'IDA total',
            'IDA blend',
            'IDA only',
            'Not classified',
            'Latin America & Caribbean (excluding high income)',
            'Latin America & Caribbean',
            'Least developed countries: UN classification',
            'Low income',
            'Lower middle income',
            'Low & middle income',
            'Late-demographic dividend',
            'Middle East & North Africa',
            'Middle income',
            'Middle East & North Africa (excluding high income)',
            'OECD members',
            'Other small states',
            'Pre-demographic dividend',
            'Pacific island small states',
            'Post-demographic dividend',
            'Sub-Saharan Africa (excluding high income)',
            'East Asia & Pacific (IDA & IBRD countries)',
            'Europe & Central Asia (IDA & IBRD countries)',
            'Latin America & the Caribbean (IDA & IBRD countries)',
            'Middle East & North Africa (IDA & IBRD countries)',
            'South Asia (IDA & IBRD)',
            'Sub-Saharan Africa (IDA & IBRD countries)',
            'Upper middle income',
            'World',
           'North America', 'Sub-Saharan Africa']
