# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib notebook

# %%
df = pd.read_csv("C:/Users/elkha/Desktop/gdp_data/API_NY.GDP.MKTP.CD_DS2_en_csv_v2_1345540.csv", skiprows=4)

# %%
df
# Out:
#      Country Name Country Code     Indicator Name  Indicator Code  \
# 0           Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 1     Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 2          Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 3         Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 4         Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD
# ..            ...          ...                ...             ...
# 259        Kosovo          XKX  GDP (current US$)  NY.GDP.MKTP.CD
# 260   Yemen, Rep.          YEM  GDP (current US$)  NY.GDP.MKTP.CD
# 261  South Africa          ZAF  GDP (current US$)  NY.GDP.MKTP.CD
# 262        Zambia          ZMB  GDP (current US$)  NY.GDP.MKTP.CD
# 263      Zimbabwe          ZWE  GDP (current US$)  NY.GDP.MKTP.CD
#
#              1960          1961          1962          1963          1964  \
# 0             NaN           NaN           NaN           NaN           NaN
# ...

# %%
non_wanted=['Arab World',
            'Central Europe and the Baltics',
            'Channel Islands',
            'East Asia & Pacific (excluding high income)',
            'Early-demographic dividend',
            'East Asia & Pacific',
            'Europe & Central Asia (excluding high income)',
            'Europe & Central Asia', 
            'Euro area',
            'European Union',
            'Fragile and conflict affected situations',
            'High income',
            'Heavily indebted poor countries (HIPC)',
            'IBRD only',
            'IDA & IBRD total',
            'IDA total',
            'IDA blend',
            'IDA only',
            'Not classified',
            'Latin America & Caribbean (excluding high income)',
            'Latin America & Caribbean',
            'Least developed countries: UN classification',
            'Low income',
            'Lower middle income',
            'Low & middle income',
            'Late-demographic dividend',
            'Middle East & North Africa',
            'Middle income',
            'Middle East & North Africa (excluding high income)',
            'OECD members',
            'Other small states',
            'Pre-demographic dividend',
            'Pacific island small states',
            'Post-demographic dividend',
            'Sub-Saharan Africa (excluding high income)',
            'East Asia & Pacific (IDA & IBRD countries)',
            'Europe & Central Asia (IDA & IBRD countries)',
            'Latin America & the Caribbean (IDA & IBRD countries)',
            'Middle East & North Africa (IDA & IBRD countries)',
            'South Asia (IDA & IBRD)',
            'Sub-Saharan Africa (IDA & IBRD countries)',
            'Upper middle income',
            'World',
           'North America', 'Sub-Saharan Africa','South Asia']

# %%
for index, row in df.iterrows(): 
    if ((row["Country Name"] in non_wanted )== True): 
        df.drop(index, inplace=True)

# %%
df
# Out:
#      Country Name Country Code     Indicator Name  Indicator Code  \
# 0           Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 1     Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 2          Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 3         Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 4         Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD
# ..            ...          ...                ...             ...
# 259        Kosovo          XKX  GDP (current US$)  NY.GDP.MKTP.CD
# 260   Yemen, Rep.          YEM  GDP (current US$)  NY.GDP.MKTP.CD
# 261  South Africa          ZAF  GDP (current US$)  NY.GDP.MKTP.CD
# 262        Zambia          ZMB  GDP (current US$)  NY.GDP.MKTP.CD
# 263      Zimbabwe          ZWE  GDP (current US$)  NY.GDP.MKTP.CD
#
#              1960          1961          1962          1963          1964  \
# 0             NaN           NaN           NaN           NaN           NaN
# ...

# %%
data_2019=df.sort_values(by='2019', ascending=False)

# %%
data_2019.head(12)
# Out:
#            Country Name Country Code     Indicator Name  Indicator Code  \
# 249       United States          USA  GDP (current US$)  NY.GDP.MKTP.CD
# 38                China          CHN  GDP (current US$)  NY.GDP.MKTP.CD
# 117               Japan          JPN  GDP (current US$)  NY.GDP.MKTP.CD
# 53              Germany          DEU  GDP (current US$)  NY.GDP.MKTP.CD
# 107               India          IND  GDP (current US$)  NY.GDP.MKTP.CD
# 79       United Kingdom          GBR  GDP (current US$)  NY.GDP.MKTP.CD
# 75               France          FRA  GDP (current US$)  NY.GDP.MKTP.CD
# 114               Italy          ITA  GDP (current US$)  NY.GDP.MKTP.CD
# 27               Brazil          BRA  GDP (current US$)  NY.GDP.MKTP.CD
# 33               Canada          CAN  GDP (current US$)  NY.GDP.MKTP.CD
# 200  Russian Federation          RUS  GDP (current US$)  NY.GDP.MKTP.CD
# 124         Korea, Rep.          KOR  GDP (current US$)  NY.GDP.MKTP.CD
#
# ...

# %%
top_12=data_2019.head(12)

# %%
years=[]
for i in range (1960,2020,1): 
    years.append(str(i))

# %%
years.append("Country Name")

# %%
years
# Out:
# ['1960',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  'Country Name']

# %%
top_12=top_12[years]

# %%
top_12
# Out:
#              1960          1961          1962          1963          1964  \
# 249  5.433000e+11  5.633000e+11  6.051000e+11  6.386000e+11  6.858000e+11
# 38   5.971647e+10  5.005687e+10  4.720936e+10  5.070680e+10  5.970834e+10
# 117  4.430734e+10  5.350862e+10  6.072302e+10  6.949813e+10  8.174901e+10
# 53            NaN           NaN           NaN           NaN           NaN
# 107  3.702988e+10  3.923244e+10  4.216148e+10  4.842192e+10  5.648029e+10
# 79   7.323397e+10  7.774197e+10  8.124756e+10  8.656196e+10  9.440756e+10
# 75   6.222548e+10  6.746164e+10  7.560753e+10  8.475920e+10  9.400785e+10
# 114  4.038529e+10  4.484276e+10  5.038389e+10  5.771074e+10  6.317542e+10
# 27   1.516557e+10  1.523685e+10  1.992629e+10  2.302148e+10  2.121189e+10
# 33   4.046172e+10  4.093495e+10  4.222745e+10  4.502999e+10  4.937752e+10
# 200           NaN           NaN           NaN           NaN           NaN
# 124  3.958191e+09  2.417558e+09  2.814319e+09  3.988785e+09  3.458939e+09
#
# ...

# %%
Xsticks= np.arange(1960,2020,5)
Xsticks=np.append(Xsticks, 2019)

x=np.arange(0,60,5)
x=np.append(x, 59)

colors=['navy','red','lightcoral','darkorchid','green','lightskyblue','indigo','fuchsia','lime','royalblue','slategrey','indianred']
plt.figure(figsize=(10,8))


for i in range (0,12,1): 
    Y=top_12.iloc[i].values[0:60]
    label=top_12.iloc[i].values[60]
    plt.plot(Y, '-', label=label,color=colors[i])

    
Xaxis = plt.gca().xaxis
ax=plt.gca()
plt.legend()
ax.set_title('GDP Growth of The Richest Countries in The World ')
plt.xticks(x,Xsticks)


for item in Xaxis.get_ticklabels():
    item.set_rotation(45)
    
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.2453669268239">
